# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
Lane: Refresh / Content Opportunity Scoring

Reason:
I chose this lane because businesses cannot manually review thousands of webpages. I want to build a system that ranks pages based on their likelihood of needing a content refresh.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision: My project helps decide which webpages should be reviewed first for a content refresh based on their search performance and engagement metrics.

Who acts on it: The primary users are SEO specialists, content managers, or digital marketing teams responsible for maintaining website performance.

Action: The ranked recommendations help them decide whether to refresh, expand, rewrite, monitor, or leave a page unchanged instead of manually reviewing every page.

Cost of a wrong recommendation: If the model recommends the wrong pages, the team may spend time and resources updating pages that are unlikely to improve while overlooking pages that genuinely need attention. The goal of this project is to support better prioritization, not to replace human judgment.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
Rows, Columns: (30000, 44)

Trend Direction:
trend_direction
down      16262
stable     5962
up         4388
new        2236
flat       1152
Name: count, dtype: int64

Average Impressions:
5200.3663

Average Sessions:
37.066633333333336

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This notebook explores patterns in historical data.
The analysis does not prove that refreshing a page will increase traffic.
The goal is to prioritize pages for human review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
